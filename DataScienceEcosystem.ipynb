# %% [markdown]
# #Exercise 2: Create markdown cell with title of the notebook.
# Create a markdown cell with the title Data Science Tools and Ecosystem using H1 style heading.
# # Data Science Tools and Ecosystem

# %% [markdown]
# #Exercise 3 - Create a markdown cell for an introduction. Write an introductory sentence about the notebook such as the follows:
#
# **In this notebook, Data Science Tools and Ecosystem are summarized.**

# %% [markdown]
# #Exercise 10 - Insert a markdown cell to list Objectives
# **Objectives**
# - List of Data Science Languages
# - List of Data Science Library
# - Table of Data Science Tools
# - Example of arithmetic equation in Python

# %% [markdown]
# #Exercise 4 - Create a markdown cell to list data science languages.Then create an ordered list (i.e. numbered) listing 3 (or more) commonly used languages for data science.
#
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. C
# 4. C++
# 5. Java
# 6. SQL
# 7. Julia

# %% [markdown]
# #Exercise 5 - Create a markdown cell to list data science libraries.Below this line add an ordered list listing 3 (or more) commonly used libraries in data science.
#
# Some of the commonly used libraries used by Data Scientists include:
# 1. Pandas
# 2. NumPY
# 3. Apache Spark
# 4. PYtorch
# 5. R library

# %% [markdown]
# #Exercise 6 - Create a markdown cell with a table of Data Science tools
# |Data Science Tools|
# |------------------|
# |Jupyter Notebook|
# |RStudio|
# |Spyder|

# %% [markdown]
# #Exercise 7 - Create a markdown cell introducing arithmetic expression examples
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
#Exercise 8 - Create a code cell to multiply and add numbers
#This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %% [markdown]
# #Exercise 9 - Create a code cell to convert minutes to hours

# %%
#This will convert 200 minutes to hours by diving by 60
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# #Exercise 11 - Create a markdown cell to indicate the Author's name
# ## Author
# Satakshi
